# %% [markdown]
# ## Data Preprocessing:
#
# #### - Lowercasing
# #### - Stemming
# #### - Lemmatization
# #### - Stopwords removal
# #### - Normalization
# #### - Tokenization
# #### - POS Tagging
# #### - Special Character Removal
# #### - Missing and Duplicate Values

# %%
headlines_df = pd.read_csv("IndianFinancialNews1.csv")

# %%
headlines_df
# Out:
#        Unnamed: 0                        Date  \
# 0               0       May 26, 2020, Tuesday
# 1               1       May 26, 2020, Tuesday
# 2               2        May 25, 2020, Monday
# 3               3        May 24, 2020, Sunday
# 4               4      May 23, 2020, Saturday
# ...           ...                         ...
# 49995       49995  February 11, 2003, Tuesday
# 49996       49996  February 11, 2003, Tuesday
# 49997       49997   February 10, 2003, Monday
# 49998       49998   February 10, 2003, Monday
# 49999       49999   February 10, 2003, Monday
#
#                                                    Title  \
# 0      ATMs to become virtual bank branches, accept d...
# 1      IDFC First Bank seniors to forgo 65% of bonus ...
# 2      Huge scam in YES Bank for many years, says Enf...
# 3      Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4      DCB Bank's profit before tax declines 37.6% to...
# ...                                                  ...
# ...

# %%
headlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   50000 non-null  int64
#  1   Date         50000 non-null  object
#  2   Title        50000 non-null  object
#  3   Description  49290 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.5+ MB

# %%
Indian_title_df = headlines_df.loc[:,['Date','Title','Description']]

# %%
Indian_title_df.head()
# Out:
#                      Date                                              Title  \
# 0   May 26, 2020, Tuesday  ATMs to become virtual bank branches, accept d...
# 1   May 26, 2020, Tuesday  IDFC First Bank seniors to forgo 65% of bonus ...
# 2    May 25, 2020, Monday  Huge scam in YES Bank for many years, says Enf...
# 3    May 24, 2020, Sunday  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4  May 23, 2020, Saturday  DCB Bank's profit before tax declines 37.6% to...
#
#                                          Description
# 0  Close to 14.6 per cent (or 35,000) of the 240,...
# 1  V Vaidyanathan, managing director and chief ex...
# 2  Rana Kapoor's wife also charged with abetting ...
# 3  The bank said it was now gearing up to extend ...
# 4  Net profit for the financial year ended March ...

# %%
Indian_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         50000 non-null  object
#  1   Title        50000 non-null  object
#  2   Description  49290 non-null  object
# dtypes: object(3)
# memory usage: 1.1+ MB

# %%
Indian_title_df.isnull().sum()
# Out:
# Date             0
# Title            0
# Description    710
# dtype: int64

# %%
round(100*(Indian_title_df.isnull().sum()/len(Indian_title_df.index)), 2)
# Out:
# Date           0.00
# Title          0.00
# Description    1.42
# dtype: float64

# %%
# Convert time column in date-time format
Indian_title_df['Date'] = pd.to_datetime(Indian_title_df['Date'], utc=True)

# %%
Indian_title_df.head()
# Out:
#                        Date  \
# 0 2020-05-26 00:00:00+00:00
# 1 2020-05-26 00:00:00+00:00
# 2 2020-05-25 00:00:00+00:00
# 3 2020-05-24 00:00:00+00:00
# 4 2020-05-23 00:00:00+00:00
#
#                                                Title  \
# 0  ATMs to become virtual bank branches, accept d...
# 1  IDFC First Bank seniors to forgo 65% of bonus ...
# 2  Huge scam in YES Bank for many years, says Enf...
# 3  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4  DCB Bank's profit before tax declines 37.6% to...
#
#                                          Description
# 0  Close to 14.6 per cent (or 35,000) of the 240,...
# 1  V Vaidyanathan, managing director and chief ex...
# 2  Rana Kapoor's wife also charged with abetting ...
# 3  The bank said it was now gearing up to extend ...
# 4  Net profit for the financial year ended March ...

# %%
Indian_title_df = Indian_title_df.loc[:,['Date','Title']]

# %%
Indian_title_df.head()
# Out:
#                        Date                                              Title
# 0 2020-05-26 00:00:00+00:00  ATMs to become virtual bank branches, accept d...
# 1 2020-05-26 00:00:00+00:00  IDFC First Bank seniors to forgo 65% of bonus ...
# 2 2020-05-25 00:00:00+00:00  Huge scam in YES Bank for many years, says Enf...
# 3 2020-05-24 00:00:00+00:00  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4 2020-05-23 00:00:00+00:00  DCB Bank's profit before tax declines 37.6% to...

# %%
Indian_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50000 non-null  datetime64[ns, UTC]
#  1   Title   50000 non-null  object
# dtypes: datetime64[ns, UTC](1), object(1)
# memory usage: 781.4+ KB

# %%
Indian_title_df = Indian_title_df.loc[:,['Date','Title']]

# %%
Indian_title_df.head()
# Out:
#                        Date                                              Title
# 0 2020-05-26 00:00:00+00:00  ATMs to become virtual bank branches, accept d...
# 1 2020-05-26 00:00:00+00:00  IDFC First Bank seniors to forgo 65% of bonus ...
# 2 2020-05-25 00:00:00+00:00  Huge scam in YES Bank for many years, says Enf...
# 3 2020-05-24 00:00:00+00:00  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4 2020-05-23 00:00:00+00:00  DCB Bank's profit before tax declines 37.6% to...

# %%
Indian_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50000 non-null  datetime64[ns, UTC]
#  1   Title   50000 non-null  object
# dtypes: datetime64[ns, UTC](1), object(1)
# memory usage: 781.4+ KB

# %%
global_headlines_df = pd.read_csv("Full-Economic-News.csv", encoding = "ISO-8859-1")

# %%
global_headlines_df.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  842613455    False   finalized                   3     12/5/15 17:48
# 1  842613456    False   finalized                   3     12/5/15 16:54
# 2  842613457    False   finalized                   3      12/5/15 1:59
# 3  842613458    False   finalized                   3      12/5/15 2:19
# 4  842613459    False   finalized                   3     12/5/15 17:48
#
#    positivity  positivity:confidence relevance  relevance:confidence  \
# 0         3.0                 0.6400       yes                 0.640
# 1         NaN                    NaN        no                 1.000
# 2         NaN                    NaN        no                 1.000
# 3         NaN                 0.0000        no                 0.675
# 4         3.0                 0.3257       yes                 0.640
#
#        articleid      date                                           headline  \
# ...

# %%
global_headlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               8000 non-null   int64
#  1   _golden                8000 non-null   bool
#  2   _unit_state            8000 non-null   object
#  3   _trusted_judgments     8000 non-null   int64
#  4   _last_judgment_at      8000 non-null   object
#  5   positivity             1420 non-null   float64
#  6   positivity:confidence  3775 non-null   float64
#  7   relevance              8000 non-null   object
#  8   relevance:confidence   8000 non-null   float64
#  9   articleid              8000 non-null   object
#  10  date                   8000 non-null   object
#  11  headline               8000 non-null   object
#  12  positivity_gold        0 non-null      float64
#  13  relevance_gold         0 non-null      float64
# ...

# %%
round(100*(global_headlines_df.isnull().sum()/len(global_headlines_df.index)), 2)
# Out:
# _unit_id                   0.00
# _golden                    0.00
# _unit_state                0.00
# _trusted_judgments         0.00
# _last_judgment_at          0.00
# positivity                82.25
# positivity:confidence     52.81
# relevance                  0.00
# relevance:confidence       0.00
# articleid                  0.00
# date                       0.00
# headline                   0.00
# positivity_gold          100.00
# relevance_gold           100.00
# text                       0.00
# dtype: float64

# %%
global_headlines_df = global_headlines_df.loc[:,['date','articleid','headline']]

# %%
global_headlines_df
# Out:
#           date       articleid  \
# 0      8/14/91   wsj_398217788
# 1      8/21/07   wsj_399019502
# 2     11/14/91   wsj_398284048
# 3      6/16/86   wsj_397959018
# 4      10/4/02   wsj_398838054
# ...        ...             ...
# 7995   2/11/52  wapo_152454634
# 7996  12/13/09  wapo_410349039
# 7997  12/18/09  wapo_410346237
# 7998   1/10/95  wapo_307808606
# 7999   4/18/67  wapo_143151328
#
#                                                headline
# 0                 Yields on CDs Fell in the Latest Week
# 1     The Morning Brief: White House Seeks to Limit ...
# 2     Banking Bill Negotiators Set Compromise --- Pl...
# 3     Manager's Journal: Sniffing Out Drug Abusers I...
# 4     Currency Trading: Dollar Remains in Tight Rang...
# ...                                                 ...
# 7995  Sawyer Sees Strong Economy For 2 Years, Truce ...
# 7996                   Oil's losses are airlines' gains
# 7997  Full Senate to vote on Bernanke; PANEL ADVANCE...
# ...

# %%
global_headlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       8000 non-null   object
#  1   articleid  8000 non-null   object
#  2   headline   8000 non-null   object
# dtypes: object(3)
# memory usage: 187.6+ KB

# %%
# Convert time column in date-time format
global_headlines_df['date'] = pd.to_datetime(global_headlines_df['date'], utc=True)

# %%
global_headlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       8000 non-null   datetime64[ns, UTC]
#  1   articleid  8000 non-null   object
#  2   headline   8000 non-null   object
# dtypes: datetime64[ns, UTC](1), object(2)
# memory usage: 187.6+ KB

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-08-14 00:00:00+00:00  wsj_398217788
# 1 2007-08-21 00:00:00+00:00  wsj_399019502
# 2 1991-11-14 00:00:00+00:00  wsj_398284048
# 3 1986-06-16 00:00:00+00:00  wsj_397959018
# 4 2002-10-04 00:00:00+00:00  wsj_398838054
#
#                                             headline
# 0              Yields on CDs Fell in the Latest Week
# 1  The Morning Brief: White House Seeks to Limit ...
# 2  Banking Bill Negotiators Set Compromise --- Pl...
# 3  Manager's Journal: Sniffing Out Drug Abusers I...
# 4  Currency Trading: Dollar Remains in Tight Rang...

# %%
Indian_title_df.head()
# Out:
#                        Date                                              Title
# 0 2020-05-26 00:00:00+00:00  ATMs to become virtual bank branches, accept d...
# 1 2020-05-26 00:00:00+00:00  IDFC First Bank seniors to forgo 65% of bonus ...
# 2 2020-05-25 00:00:00+00:00  Huge scam in YES Bank for many years, says Enf...
# 3 2020-05-24 00:00:00+00:00  Bank of Maharashtra sanctioned Rs 2,789 cr in ...
# 4 2020-05-23 00:00:00+00:00  DCB Bank's profit before tax declines 37.6% to...

# %%
Indian_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    50000 non-null  datetime64[ns, UTC]
#  1   Title   50000 non-null  object
# dtypes: datetime64[ns, UTC](1), object(1)
# memory usage: 781.4+ KB

# %%
# !pip install nltk==3.4

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\saura\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

negative = []
for row in range(len(Indian_title_df)):
    negative.append(analyzer.polarity_scores(Indian_title_df['Title'].iloc[row])['neg'])
    
Indian_title_df['negative_score'] = negative

# %%
Indian_title_df
# Out:
#                            Date  \
# 0     2020-05-26 00:00:00+00:00
# 1     2020-05-26 00:00:00+00:00
# 2     2020-05-25 00:00:00+00:00
# 3     2020-05-24 00:00:00+00:00
# 4     2020-05-23 00:00:00+00:00
# ...                         ...
# 49995 2003-02-11 00:00:00+00:00
# 49996 2003-02-11 00:00:00+00:00
# 49997 2003-02-10 00:00:00+00:00
# 49998 2003-02-10 00:00:00+00:00
# 49999 2003-02-10 00:00:00+00:00
#
#                                                    Title  negative_score
# 0      ATMs to become virtual bank branches, accept d...           0.000
# 1      IDFC First Bank seniors to forgo 65% of bonus ...           0.233
# 2      Huge scam in YES Bank for many years, says Enf...           0.212
# 3      Bank of Maharashtra sanctioned Rs 2,789 cr in ...           0.000
# 4      DCB Bank's profit before tax declines 37.6% to...           0.000
# ...                                                  ...             ...
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

positive = []
for row in range(len(Indian_title_df)):
    positive.append(analyzer.polarity_scores(Indian_title_df['Title'].iloc[row])['pos'])

Indian_title_df['positive_score'] = positive
#news_title_df = news_title_df[(news_title_df[['negative_score']] == 0).all(axis=1)].reset_index(drop=True)

Indian_title_df
# Out:
#                            Date  \
# 0     2020-05-26 00:00:00+00:00
# 1     2020-05-26 00:00:00+00:00
# 2     2020-05-25 00:00:00+00:00
# 3     2020-05-24 00:00:00+00:00
# 4     2020-05-23 00:00:00+00:00
# ...                         ...
# 49995 2003-02-11 00:00:00+00:00
# 49996 2003-02-11 00:00:00+00:00
# 49997 2003-02-10 00:00:00+00:00
# 49998 2003-02-10 00:00:00+00:00
# 49999 2003-02-10 00:00:00+00:00
#
#                                                    Title  negative_score  \
# 0      ATMs to become virtual bank branches, accept d...           0.000
# 1      IDFC First Bank seniors to forgo 65% of bonus ...           0.233
# 2      Huge scam in YES Bank for many years, says Enf...           0.212
# 3      Bank of Maharashtra sanctioned Rs 2,789 cr in ...           0.000
# 4      DCB Bank's profit before tax declines 37.6% to...           0.000
# ...                                                  ...             ...
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

neutral = []
for row in range(len(Indian_title_df)):
    neutral.append(analyzer.polarity_scores(Indian_title_df['Title'].iloc[row])['neu'])

Indian_title_df['neutral_score'] = neutral
#news_title_df = news_title_df[(news_title_df[['negative_score']] == 0).all(axis=1)].reset_index(drop=True)

Indian_title_df
# Out:
#                            Date  \
# 0     2020-05-26 00:00:00+00:00
# 1     2020-05-26 00:00:00+00:00
# 2     2020-05-25 00:00:00+00:00
# 3     2020-05-24 00:00:00+00:00
# 4     2020-05-23 00:00:00+00:00
# ...                         ...
# 49995 2003-02-11 00:00:00+00:00
# 49996 2003-02-11 00:00:00+00:00
# 49997 2003-02-10 00:00:00+00:00
# 49998 2003-02-10 00:00:00+00:00
# 49999 2003-02-10 00:00:00+00:00
#
#                                                    Title  negative_score  \
# 0      ATMs to become virtual bank branches, accept d...           0.000
# 1      IDFC First Bank seniors to forgo 65% of bonus ...           0.233
# 2      Huge scam in YES Bank for many years, says Enf...           0.212
# 3      Bank of Maharashtra sanctioned Rs 2,789 cr in ...           0.000
# 4      DCB Bank's profit before tax declines 37.6% to...           0.000
# ...                                                  ...             ...
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

cs = []
for row in range(len(Indian_title_df)):
    cs.append(analyzer.polarity_scores(Indian_title_df['Title'].iloc[row])['compound'])

Indian_title_df['compound_vader_score'] = cs
Indian_title_df = Indian_title_df[(Indian_title_df[['compound_vader_score']] != 0).all(axis=1)].reset_index(drop=True)

Indian_title_df
# Out:
#                            Date  \
# 0     2020-05-26 00:00:00+00:00
# 1     2020-05-26 00:00:00+00:00
# 2     2020-05-25 00:00:00+00:00
# 3     2020-05-23 00:00:00+00:00
# 4     2020-05-22 00:00:00+00:00
# ...                         ...
# 22436 2003-02-12 00:00:00+00:00
# 22437 2003-02-12 00:00:00+00:00
# 22438 2003-02-12 00:00:00+00:00
# 22439 2003-02-11 00:00:00+00:00
# 22440 2003-02-11 00:00:00+00:00
#
#                                                    Title  negative_score  \
# 0      ATMs to become virtual bank branches, accept d...           0.000
# 1      IDFC First Bank seniors to forgo 65% of bonus ...           0.233
# 2      Huge scam in YES Bank for many years, says Enf...           0.212
# 3      DCB Bank's profit before tax declines 37.6% to...           0.000
# 4      Retail, MSME loans to get cheaper as RBI cuts ...           0.135
# ...                                                  ...             ...
# ...

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-08-14 00:00:00+00:00  wsj_398217788
# 1 2007-08-21 00:00:00+00:00  wsj_399019502
# 2 1991-11-14 00:00:00+00:00  wsj_398284048
# 3 1986-06-16 00:00:00+00:00  wsj_397959018
# 4 2002-10-04 00:00:00+00:00  wsj_398838054
#
#                                             headline
# 0              Yields on CDs Fell in the Latest Week
# 1  The Morning Brief: White House Seeks to Limit ...
# 2  Banking Bill Negotiators Set Compromise --- Pl...
# 3  Manager's Journal: Sniffing Out Drug Abusers I...
# 4  Currency Trading: Dollar Remains in Tight Rang...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

negative = []
for row in range(len(global_headlines_df)):
    negative.append(analyzer.polarity_scores(global_headlines_df['headline'].iloc[row])['neg'])
    
global_headlines_df['negative_score'] = negative

# %%
global_headlines_df
# Out:
#                           date       articleid  \
# 0    1991-08-14 00:00:00+00:00   wsj_398217788
# 1    2007-08-21 00:00:00+00:00   wsj_399019502
# 2    1991-11-14 00:00:00+00:00   wsj_398284048
# 3    1986-06-16 00:00:00+00:00   wsj_397959018
# 4    2002-10-04 00:00:00+00:00   wsj_398838054
# ...                        ...             ...
# 7995 2052-02-11 00:00:00+00:00  wapo_152454634
# 7996 2009-12-13 00:00:00+00:00  wapo_410349039
# 7997 2009-12-18 00:00:00+00:00  wapo_410346237
# 7998 1995-01-10 00:00:00+00:00  wapo_307808606
# 7999 2067-04-18 00:00:00+00:00  wapo_143151328
#
#                                                headline  negative_score
# 0                 Yields on CDs Fell in the Latest Week           0.000
# 1     The Morning Brief: White House Seeks to Limit ...           0.000
# 2     Banking Bill Negotiators Set Compromise --- Pl...           0.000
# 3     Manager's Journal: Sniffing Out Drug Abusers I...           0.420
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

positive = []
for row in range(len(global_headlines_df)):
    positive.append(analyzer.polarity_scores(global_headlines_df['headline'].iloc[row])['pos'])

global_headlines_df['positive_score'] = positive
#news_title_df = news_title_df[(news_title_df[['negative_score']] == 0).all(axis=1)].reset_index(drop=True)

global_headlines_df
# Out:
#                           date       articleid  \
# 0    1991-08-14 00:00:00+00:00   wsj_398217788
# 1    2007-08-21 00:00:00+00:00   wsj_399019502
# 2    1991-11-14 00:00:00+00:00   wsj_398284048
# 3    1986-06-16 00:00:00+00:00   wsj_397959018
# 4    2002-10-04 00:00:00+00:00   wsj_398838054
# ...                        ...             ...
# 7995 2052-02-11 00:00:00+00:00  wapo_152454634
# 7996 2009-12-13 00:00:00+00:00  wapo_410349039
# 7997 2009-12-18 00:00:00+00:00  wapo_410346237
# 7998 1995-01-10 00:00:00+00:00  wapo_307808606
# 7999 2067-04-18 00:00:00+00:00  wapo_143151328
#
#                                                headline  negative_score  \
# 0                 Yields on CDs Fell in the Latest Week           0.000
# 1     The Morning Brief: White House Seeks to Limit ...           0.000
# 2     Banking Bill Negotiators Set Compromise --- Pl...           0.000
# 3     Manager's Journal: Sniffing Out Drug Abusers I...           0.420
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

neutral = []
for row in range(len(global_headlines_df)):
    neutral.append(analyzer.polarity_scores(global_headlines_df['headline'].iloc[row])['neu'])

global_headlines_df['neutral_score'] = neutral
#news_title_df = news_title_df[(news_title_df[['negative_score']] == 0).all(axis=1)].reset_index(drop=True)

global_headlines_df
# Out:
#                           date       articleid  \
# 0    1991-08-14 00:00:00+00:00   wsj_398217788
# 1    2007-08-21 00:00:00+00:00   wsj_399019502
# 2    1991-11-14 00:00:00+00:00   wsj_398284048
# 3    1986-06-16 00:00:00+00:00   wsj_397959018
# 4    2002-10-04 00:00:00+00:00   wsj_398838054
# ...                        ...             ...
# 7995 2052-02-11 00:00:00+00:00  wapo_152454634
# 7996 2009-12-13 00:00:00+00:00  wapo_410349039
# 7997 2009-12-18 00:00:00+00:00  wapo_410346237
# 7998 1995-01-10 00:00:00+00:00  wapo_307808606
# 7999 2067-04-18 00:00:00+00:00  wapo_143151328
#
#                                                headline  negative_score  \
# 0                 Yields on CDs Fell in the Latest Week           0.000
# 1     The Morning Brief: White House Seeks to Limit ...           0.000
# 2     Banking Bill Negotiators Set Compromise --- Pl...           0.000
# 3     Manager's Journal: Sniffing Out Drug Abusers I...           0.420
# ...

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

cs = []
for row in range(len(global_headlines_df)):
    cs.append(analyzer.polarity_scores(global_headlines_df['headline'].iloc[row])['compound'])

global_headlines_df['compound_vader_score'] = cs
global_headlines_df = global_headlines_df[(global_headlines_df[['compound_vader_score']] != 0).all(axis=1)].reset_index(drop=True)

global_headlines_df
# Out:
#                           date       articleid  \
# 0    1991-11-14 00:00:00+00:00   wsj_398284048
# 1    1986-06-16 00:00:00+00:00   wsj_397959018
# 2    2001-05-24 00:00:00+00:00   wsj_398739166
# 3    1986-10-22 00:00:00+00:00   wsj_397957465
# 4    2005-12-08 00:00:00+00:00   wsj_399004010
# ...                        ...             ...
# 4841 2060-10-08 00:00:00+00:00  wapo_141184715
# 4842 2052-02-11 00:00:00+00:00  wapo_152454634
# 4843 2009-12-13 00:00:00+00:00  wapo_410349039
# 4844 2009-12-18 00:00:00+00:00  wapo_410346237
# 4845 1995-01-10 00:00:00+00:00  wapo_307808606
#
#                                                headline  negative_score  \
# 0     Banking Bill Negotiators Set Compromise --- Pl...           0.000
# 1     Manager's Journal: Sniffing Out Drug Abusers I...           0.420
# 2     Bank of Montreal, Royal Bank Profits Rose in 2...           0.000
# 3                  Battle Over Medical Costs Isn't Over           0.342
# ...

# %% [markdown]
# ## Data Preprocessing
#
# #### Lowercasing, Stemming and Lemmatization, Stopwords removal, Tokenization etc.

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer,PorterStemmer
from nltk.corpus import stopwords
import re
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()

# %%
import string

# %%
def preprocess_data(text):
    text = text.lower()
    text = [w for w in text if w not in string.punctuation]
    
    return "".join(text)

# %%
global_headlines_df['headline'] = global_headlines_df['headline'].apply(preprocess_data)

# %% [markdown]
# ### Lowecasing of Global_headline_df

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-11-14 00:00:00+00:00  wsj_398284048
# 1 1986-06-16 00:00:00+00:00  wsj_397959018
# 2 2001-05-24 00:00:00+00:00  wsj_398739166
# 3 1986-10-22 00:00:00+00:00  wsj_397957465
# 4 2005-12-08 00:00:00+00:00  wsj_399004010
#
#                                             headline  negative_score  \
# 0  banking bill negotiators set compromise  plan ...           0.000
# 1  managers journal sniffing out drug abusers is ...           0.420
# 2  bank of montreal royal bank profits rose in 2n...           0.000
# 3                battle over medical costs isnt over           0.342
# 4       dow falls 4595 late gm surge stanches losses           0.278
#
#    positive_score  neutral_score  compound_vader_score
# 0           0.109          0.891                0.2960
# 1           0.000          0.580               -0.7003
# 2           0.244          0.756                0.4404
# 3           0.000          0.658               -0.3818
# ...

# %%
Indian_title_df['Title'] = Indian_title_df['Title'].apply(preprocess_data)

# %% [markdown]
# ### Lowercasing of Indian_Title_df

# %%
Indian_title_df.head()
# Out:
#                        Date  \
# 0 2020-05-26 00:00:00+00:00
# 1 2020-05-26 00:00:00+00:00
# 2 2020-05-25 00:00:00+00:00
# 3 2020-05-23 00:00:00+00:00
# 4 2020-05-22 00:00:00+00:00
#
#                                                Title  negative_score  \
# 0  atms to become virtual bank branches accept de...           0.000
# 1  idfc first bank seniors to forgo 65 of bonus a...           0.233
# 2  huge scam in yes bank for many years says enfo...           0.212
# 3  dcb banks profit before tax declines 376 to rs...           0.000
# 4  retail msme loans to get cheaper as rbi cuts r...           0.135
#
#    positive_score  neutral_score  compound_vader_score
# 0           0.366          0.634                0.6369
# 1           0.199          0.568               -0.1531
# 2           0.329          0.459                0.2577
# 3           0.195          0.805                0.4404
# 4           0.129          0.736               -0.0258

# %%
import pandas as pd, numpy as np, re, time
from nltk.stem.porter import PorterStemmer

# %%
#from sklearn.model_selection import train_test_split
#from sklearn.metrics import confusion_matrix
#from sklearn.svm import LinearSVC
#from sklearn.model_selection import cross_val_score
#from sklearn.naive_bayes import GaussianNB
#from sklearn.linear_model import LogisticRegression
#from sklearn.ensemble import RandomForestClassifier

# %%
# Relacing special symbols and digits in headline column
# re stands for Regular Expression
global_headlines_df['headline'] = global_headlines_df['headline'].apply(lambda s : re.sub('[^a-zA-Z]', ' ', s))

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-11-14 00:00:00+00:00  wsj_398284048
# 1 1986-06-16 00:00:00+00:00  wsj_397959018
# 2 2001-05-24 00:00:00+00:00  wsj_398739166
# 3 1986-10-22 00:00:00+00:00  wsj_397957465
# 4 2005-12-08 00:00:00+00:00  wsj_399004010
#
#                                             headline  negative_score  \
# 0  banking bill negotiators set compromise  plan ...           0.000
# 1  managers journal sniffing out drug abusers is ...           0.420
# 2  bank of montreal royal bank profits rose in  n...           0.000
# 3                battle over medical costs isnt over           0.342
# 4       dow falls      late gm surge stanches losses           0.278
#
#    positive_score  neutral_score  compound_vader_score
# 0           0.109          0.891                0.2960
# 1           0.000          0.580               -0.7003
# 2           0.244          0.756                0.4404
# 3           0.000          0.658               -0.3818
# ...

# %%
global_headlines_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  4846 non-null   datetime64[ns, UTC]
#  1   articleid             4846 non-null   object
#  2   headline              4846 non-null   object
#  3   negative_score        4846 non-null   float64
#  4   positive_score        4846 non-null   float64
#  5   neutral_score         4846 non-null   float64
#  6   compound_vader_score  4846 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(4), object(2)
# memory usage: 265.1+ KB

# %% [markdown]
# ### Remove the un-necessary noise from the headlines

# %%
noise_list = nltk.corpus.stopwords.words('english')

# %%
global_headlines_df['headline_new'] = global_headlines_df['headline'].apply(lambda x: [i for i in x.split() if i not in noise_list])

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-11-14 00:00:00+00:00  wsj_398284048
# 1 1986-06-16 00:00:00+00:00  wsj_397959018
# 2 2001-05-24 00:00:00+00:00  wsj_398739166
# 3 1986-10-22 00:00:00+00:00  wsj_397957465
# 4 2005-12-08 00:00:00+00:00  wsj_399004010
#
#                                             headline  negative_score  \
# 0  banking bill negotiators set compromise  plan ...           0.000
# 1  managers journal sniffing out drug abusers is ...           0.420
# 2  bank of montreal royal bank profits rose in  n...           0.000
# 3                battle over medical costs isnt over           0.342
# 4       dow falls      late gm surge stanches losses           0.278
#
#    positive_score  neutral_score  compound_vader_score  \
# 0           0.109          0.891                0.2960
# 1           0.000          0.580               -0.7003
# 2           0.244          0.756                0.4404
# 3           0.000          0.658               -0.3818
# ...

# %%
global_headlines_df['headline_new']
# Out:
# 0       [banking, bill, negotiators, set, compromise, ...
# 1       [managers, journal, sniffing, drug, abusers, q...
# 2       [bank, montreal, royal, bank, profits, rose, n...
# 3                          [battle, medical, costs, isnt]
# 4         [dow, falls, late, gm, surge, stanches, losses]
#                               ...
# 4841    [stocks, rise, third, straight, session, bette...
# 4842        [sawyer, sees, strong, economy, years, truce]
# 4843                      [oils, losses, airlines, gains]
# 4844    [full, senate, vote, bernanke, panel, advances...
# 4845                         [reinventing, opportunities]
# Name: headline_new, Length: 4846, dtype: object

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# %%
global_headlines_df['headline']
# Out:
# 0       banking bill negotiators set compromise  plan ...
# 1       managers journal sniffing out drug abusers is ...
# 2       bank of montreal royal bank profits rose in  n...
# 3                     battle over medical costs isnt over
# 4            dow falls      late gm surge stanches losses
#                               ...
# 4841    stocks rise for third straight session better ...
# 4842    sawyer sees strong economy for   years truce o...
# 4843                       oils losses are airlines gains
# 4844    full senate to vote on bernanke panel advances...
# 4845                            reinventing opportunities
# Name: headline, Length: 4846, dtype: object

# %%
lem = WordNetLemmatizer()

# %%
import nltk

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\saura\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
global_headlines_df['headline_new'] = global_headlines_df['headline_new'].apply(lambda x: [lem.lemmatize(i,'v') for i in x])

# %%
global_headlines_df['headline_new']
# Out:
# 0       [bank, bill, negotiators, set, compromise, pla...
# 1       [managers, journal, sniff, drug, abusers, quic...
# 2       [bank, montreal, royal, bank, profit, rise, nd...
# 3                           [battle, medical, cost, isnt]
# 4            [dow, fall, late, gm, surge, stanch, losses]
#                               ...
# 4841    [stock, rise, third, straight, session, better...
# 4842         [sawyer, see, strong, economy, years, truce]
# 4843                        [oil, losses, airlines, gain]
# 4844    [full, senate, vote, bernanke, panel, advance,...
# 4845                            [reinvent, opportunities]
# Name: headline_new, Length: 4846, dtype: object

# %% [markdown]
# ### Relacing special symbols and digits in headline column

# %%
# re stands for Regular Expression
Indian_title_df['Title'] = Indian_title_df['Title'].apply(lambda s : re.sub('[^a-zA-Z]', ' ', s))

# %%
Indian_title_df.head()
# Out:
#                        Date  \
# 0 2020-05-26 00:00:00+00:00
# 1 2020-05-26 00:00:00+00:00
# 2 2020-05-25 00:00:00+00:00
# 3 2020-05-23 00:00:00+00:00
# 4 2020-05-22 00:00:00+00:00
#
#                                                Title  negative_score  \
# 0  atms to become virtual bank branches accept de...           0.000
# 1  idfc first bank seniors to forgo    of bonus a...           0.233
# 2  huge scam in yes bank for many years says enfo...           0.212
# 3  dcb banks profit before tax declines     to rs...           0.000
# 4  retail msme loans to get cheaper as rbi cuts r...           0.135
#
#    positive_score  neutral_score  compound_vader_score
# 0           0.366          0.634                0.6369
# 1           0.199          0.568               -0.1531
# 2           0.329          0.459                0.2577
# 3           0.195          0.805                0.4404
# 4           0.129          0.736               -0.0258

# %%
Indian_title_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22441 entries, 0 to 22440
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  22441 non-null  datetime64[ns, UTC]
#  1   Title                 22441 non-null  object
#  2   negative_score        22441 non-null  float64
#  3   positive_score        22441 non-null  float64
#  4   neutral_score         22441 non-null  float64
#  5   compound_vader_score  22441 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(4), object(1)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Remove the unncessary noise from the headline

# %%
noise_list1 = nltk.corpus.stopwords.words('english')

# %%
Indian_title_df['Title_new'] = Indian_title_df['Title'].apply(lambda x: [i for i in x.split() if i not in noise_list])

# %%
Indian_title_df.head()
# Out:
#                        Date  \
# 0 2020-05-26 00:00:00+00:00
# 1 2020-05-26 00:00:00+00:00
# 2 2020-05-25 00:00:00+00:00
# 3 2020-05-23 00:00:00+00:00
# 4 2020-05-22 00:00:00+00:00
#
#                                                Title  negative_score  \
# 0  atms to become virtual bank branches accept de...           0.000
# 1  idfc first bank seniors to forgo    of bonus a...           0.233
# 2  huge scam in yes bank for many years says enfo...           0.212
# 3  dcb banks profit before tax declines     to rs...           0.000
# 4  retail msme loans to get cheaper as rbi cuts r...           0.135
#
#    positive_score  neutral_score  compound_vader_score  \
# 0           0.366          0.634                0.6369
# 1           0.199          0.568               -0.1531
# 2           0.329          0.459                0.2577
# 3           0.195          0.805                0.4404
# 4           0.129          0.736               -0.0258
#
# ...

# %%
Indian_title_df['Title_new']
# Out:
# 0        [atms, become, virtual, bank, branches, accept...
# 1        [idfc, first, bank, seniors, forgo, bonus, ami...
# 2        [huge, scam, yes, bank, many, years, says, enf...
# 3        [dcb, banks, profit, tax, declines, rs, crore, q]
# 4        [retail, msme, loans, get, cheaper, rbi, cuts,...
#                                ...
# 22436    [fitch, affirms, india, ratings, despite, defi...
# 22437               [mfg, data, war, fears, scythe, gilts]
# 22438    [irda, nixes, increase, firstyear, commission,...
# 22439    [crisil, scripts, risk, gauge, tool, film, ind...
# 22440    [lic, mops, government, securities, prices, cr...
# Name: Title_new, Length: 22441, dtype: object

# %% [markdown]
# ### Lemmatization - I would proceed with Lemmatization and would try to reduce to verbs to their roots

# %%
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

# %%
Indian_title_df['Title_new'] = Indian_title_df['Title_new'].apply(lambda x: [lem.lemmatize(i,'v') for i in x])

# %%
Indian_title_df['Title_new']
# Out:
# 0        [atms, become, virtual, bank, branch, accept, ...
# 1        [idfc, first, bank, seniors, forgo, bonus, ami...
# 2        [huge, scam, yes, bank, many, years, say, enfo...
# 3          [dcb, bank, profit, tax, decline, rs, crore, q]
# 4        [retail, msme, loan, get, cheaper, rbi, cut, r...
#                                ...
# 22436        [fitch, affirm, india, rat, despite, deficit]
# 22437                [mfg, data, war, fear, scythe, gilts]
# 22438    [irda, nix, increase, firstyear, commission, a...
# 22439    [crisil, script, risk, gauge, tool, film, indu...
# 22440     [lic, mop, government, securities, price, crash]
# Name: Title_new, Length: 22441, dtype: object

# %% [markdown]
# ### Stemming

# %%
features = global_headlines_df['headline']

# %%
global_headlines_df['headline']
# Out:
# 0       banking bill negotiators set compromise  plan ...
# 1       managers journal sniffing out drug abusers is ...
# 2       bank of montreal royal bank profits rose in  n...
# 3                     battle over medical costs isnt over
# 4            dow falls      late gm surge stanches losses
#                               ...
# 4841    stocks rise for third straight session better ...
# 4842    sawyer sees strong economy for   years truce o...
# 4843                       oils losses are airlines gains
# 4844    full senate to vote on bernanke panel advances...
# 4845                            reinventing opportunities
# Name: headline, Length: 4846, dtype: object

# %% [markdown]
# ### stemming our data

# %%
ps = PorterStemmer()

features = features.apply(lambda x: x.split())
features = features.apply(lambda x : ''.join([ps.stem(word) for word in x]))

# %%
features
# Out:
# 0       bankbillnegotisetcompromisplantowidenbankentri...
# 1                 managjournalsnifoutdrugabusisnoquickfix
# 2             bankofmontrealroyalbankprofitroseinndperiod
# 3                              battlovermediccostisntover
# 4                             dowfalllategmsurgstanchloss
#                               ...
# 4841    stockriseforthirdstraightsessionbettersalehelp...
# 4842              sawyerseestrongeconomiforyeartruceornot
# 4843                                 oillossareairlingain
# 4844    fullsenattovoteonbernankpaneladvancrenominshar...
# 4845                                     reinventopportun
# Name: headline, Length: 4846, dtype: object

# %%
global_headlines_df['headline']
# Out:
# 0       banking bill negotiators set compromise  plan ...
# 1       managers journal sniffing out drug abusers is ...
# 2       bank of montreal royal bank profits rose in  n...
# 3                     battle over medical costs isnt over
# 4            dow falls      late gm surge stanches losses
#                               ...
# 4841    stocks rise for third straight session better ...
# 4842    sawyer sees strong economy for   years truce o...
# 4843                       oils losses are airlines gains
# 4844    full senate to vote on bernanke panel advances...
# 4845                            reinventing opportunities
# Name: headline, Length: 4846, dtype: object

# %%
indian_features = Indian_title_df['Title']

# %%
Indian_title_df['Title']
# Out:
# 0        atms to become virtual bank branches accept de...
# 1        idfc first bank seniors to forgo    of bonus a...
# 2        huge scam in yes bank for many years says enfo...
# 3        dcb banks profit before tax declines     to rs...
# 4        retail msme loans to get cheaper as rbi cuts r...
#                                ...
# 22436          fitch affirms india ratings despite deficit
# 22437                      mfg data war fears scythe gilts
# 22438    irda nixes increase in firstyear commission to...
# 22439     crisil scripts risk gauge tool for film industry
# 22440    lic mops up government securities as prices crash
# Name: Title, Length: 22441, dtype: object

# %% [markdown]
# ### stemming our data

# %%
ps = PorterStemmer()

indian_features = indian_features.apply(lambda x: x.split())
indian_features = indian_features.apply(lambda x : ''.join([ps.stem(word) for word in x]))

# %%
indian_features
# Out:
# 0        atmtobecomvirtualbankbranchacceptdepositwithin...
# 1           idfcfirstbankseniortoforgoofbonuamidcovidcrisi
# 2             hugescaminyebankformaniyearsayenforcdirector
# 3                  dcbbankprofitbefortaxdeclintorscroreinq
# 4        retailmsmeloantogetcheaperasrbicutreporateinsu...
#                                ...
# 22436                    fitchaffirmindiaratedespitdeficit
# 22437                              mfgdatawarfearscythgilt
# 22438              irdanixincreasinfirstyearcommisstoagent
# 22439              crisilscriptriskgaugtoolforfilmindustri
# 22440                      licmopupgovernsecuraspricecrash
# Name: Title, Length: 22441, dtype: object

# %%
Indian_title_df['Title']
# Out:
# 0        atms to become virtual bank branches accept de...
# 1        idfc first bank seniors to forgo    of bonus a...
# 2        huge scam in yes bank for many years says enfo...
# 3        dcb banks profit before tax declines     to rs...
# 4        retail msme loans to get cheaper as rbi cuts r...
#                                ...
# 22436          fitch affirms india ratings despite deficit
# 22437                      mfg data war fears scythe gilts
# 22438    irda nixes increase in firstyear commission to...
# 22439     crisil scripts risk gauge tool for film industry
# 22440    lic mops up government securities as prices crash
# Name: Title, Length: 22441, dtype: object

# %% [markdown]
# ### Grab all the titles

# %%
indian_article_titles = Indian_title_df['Title']

# %%
indian_article_titles.head()
# Out:
# 0    atms to become virtual bank branches accept de...
# 1    idfc first bank seniors to forgo    of bonus a...
# 2    huge scam in yes bank for many years says enfo...
# 3    dcb banks profit before tax declines     to rs...
# 4    retail msme loans to get cheaper as rbi cuts r...
# Name: Title, dtype: object

# %% [markdown]
# ### Create a list of strings, one for each title

# %%
indian_titles_list = [title for title in indian_article_titles]

# %%
indian_titles_list
# Out:
# ['atms to become virtual bank branches accept deposits with instant credit',
#  'idfc first bank seniors to forgo    of bonus amid covid   crisis',
#  'huge scam in yes bank for many years says enforcement directorate',
#  'dcb banks profit before tax declines     to rs      crore in q ',
#  'retail msme loans to get cheaper as rbi cuts repo rate in surprise action',
#  'rbi forecasts economic contraction announces a sharp   bp rate cut',
#  'rbi extends loan moratorium till aug    silent on onetime restructuring',
#  'covid   crisis slippages may jump to rs    trillion says india ratings',
#  'fm sitharaman to review banking situation credit offtake with psb chiefs',
#  'bank credit growth slowed in dec quarter on muted industrial demand',
#  'covid   crisis banks seek relaxed npa norms moratorium extension',
#  'govt to use rbi money to support struggling nbfcs for just three months',
#  'rbi may need to slash rates alongside providing fiscal stimulus economists',
# ...

# %% [markdown]
# ### Collapse the list of strings into a single long string for processing

# %%
indian_big_title_string = ' '.join(indian_titles_list)

# %%
indian_big_title_string
# Out:
# 'atms to become virtual bank branches accept deposits with instant credit idfc first bank seniors to forgo    of bonus amid covid   crisis huge scam in yes bank for many years says enforcement directorate dcb banks profit before tax declines     to rs      crore in q  retail msme loans to get cheaper as rbi cuts repo rate in surprise action rbi forecasts economic contraction announces a sharp   bp rate cut rbi extends loan moratorium till aug    silent on onetime restructuring covid   crisis slippages may jump to rs    trillion says india ratings fm sitharaman to review banking situation credit offtake with psb chiefs bank credit growth slowed in dec quarter on muted industrial demand covid   crisis banks seek relaxed npa norms moratorium extension govt to use rbi money to support struggling nbfcs for just three months rbi may need to slash rates alongside providing fiscal stimulus economists psbs report sharp rise in deposits thanks to yes bank franklin fiasco moratorium to strain n
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\saura\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ### Tokenize the string into words

# %%
indian_tokens = word_tokenize(indian_big_title_string)

# %%
indian_tokens
# Out:
# ['atms',
#  'to',
#  'become',
#  'virtual',
#  'bank',
#  'branches',
#  'accept',
#  'deposits',
#  'with',
#  'instant',
#  'credit',
#  'idfc',
#  'first',
#  'bank',
#  'seniors',
#  'to',
#  'forgo',
#  'of',
#  'bonus',
#  'amid',
#  'covid',
#  'crisis',
#  'huge',
#  'scam',
#  'in',
#  'yes',
#  'bank',
#  'for',
#  'many',
#  'years',
#  'says',
#  'enforcement',
#  'directorate',
#  'dcb',
#  'banks',
#  'profit',
#  'before',
#  'tax',
#  'declines',
#  'to',
#  'rs',
#  'crore',
#  'in',
#  'q',
#  'retail',
#  'msme',
#  'loans',
#  'to',
#  'get',
#  'cheaper',
#  'as',
#  'rbi',
#  'cuts',
#  'repo',
#  'rate',
#  'in',
#  'surprise',
#  'action',
#  'rbi',
#  'forecasts',
#  'economic',
#  'contraction',
#  'announces',
#  'a',
#  'sharp',
#  'bp',
#  'rate',
#  'cut',
#  'rbi',
#  'extends',
#  'loan',
#  'moratorium',
#  'till',
#  'aug',
#  'silent',
#  'on',
#  'onetime',
#  'restructuring',
#  'covid',
#  'crisis',
#  'slippages',
#  'may',
#  'jump',
#  'to',
# ...

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\saura\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.pos_tag(indian_tokens)
# Out:
# [('atms', 'NN'),
#  ('to', 'TO'),
#  ('become', 'VB'),
#  ('virtual', 'JJ'),
#  ('bank', 'NN'),
#  ('branches', 'NNS'),
#  ('accept', 'VBP'),
#  ('deposits', 'NNS'),
#  ('with', 'IN'),
#  ('instant', 'JJ'),
#  ('credit', 'NN'),
#  ('idfc', 'NNS'),
#  ('first', 'JJ'),
#  ('bank', 'NN'),
#  ('seniors', 'NNS'),
#  ('to', 'TO'),
#  ('forgo', 'VB'),
#  ('of', 'IN'),
#  ('bonus', 'NN'),
#  ('amid', 'IN'),
#  ('covid', 'JJ'),
#  ('crisis', 'NN'),
#  ('huge', 'JJ'),
#  ('scam', 'NN'),
#  ('in', 'IN'),
#  ('yes', 'NNS'),
#  ('bank', 'NN'),
#  ('for', 'IN'),
#  ('many', 'JJ'),
#  ('years', 'NNS'),
#  ('says', 'VBZ'),
#  ('enforcement', 'NN'),
#  ('directorate', 'NN'),
#  ('dcb', 'JJ'),
#  ('banks', 'NNS'),
#  ('profit', 'NN'),
#  ('before', 'IN'),
#  ('tax', 'NN'),
#  ('declines', 'NNS'),
#  ('to', 'TO'),
#  ('rs', 'VB'),
#  ('crore', 'NN'),
#  ('in', 'IN'),
#  ('q', 'JJ'),
#  ('retail', 'JJ'),
#  ('msme', 'NN'),
#  ('loans', 'NNS'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('cheaper', 'JJR'),
# ...

# %%
indian_words
# Out:
# ['atms',
#  'to',
#  'become',
#  'virtual',
#  'bank',
#  'branches',
#  'accept',
#  'deposits',
#  'with',
#  'instant',
#  'credit',
#  'idfc',
#  'first',
#  'bank',
#  'seniors',
#  'to',
#  'forgo',
#  'of',
#  'bonus',
#  'amid',
#  'covid',
#  'crisis',
#  'huge',
#  'scam',
#  'in',
#  'yes',
#  'bank',
#  'for',
#  'many',
#  'years',
#  'says',
#  'enforcement',
#  'directorate',
#  'dcb',
#  'banks',
#  'profit',
#  'before',
#  'tax',
#  'declines',
#  'to',
#  'rs',
#  'crore',
#  'in',
#  'q',
#  'retail',
#  'msme',
#  'loans',
#  'to',
#  'get',
#  'cheaper',
#  'as',
#  'rbi',
#  'cuts',
#  'repo',
#  'rate',
#  'in',
#  'surprise',
#  'action',
#  'rbi',
#  'forecasts',
#  'economic',
#  'contraction',
#  'announces',
#  'a',
#  'sharp',
#  'bp',
#  'rate',
#  'cut',
#  'rbi',
#  'extends',
#  'loan',
#  'moratorium',
#  'till',
#  'aug',
#  'silent',
#  'on',
#  'onetime',
#  'restructuring',
#  'covid',
#  'crisis',
#  'slippages',
#  'may',
#  'jump',
#  'to',
# ...

# %% [markdown]
# ### Remove non-alphabetic tokens, such as punctuation

# %%
indian_words = [word.lower() for word in indian_tokens if word.isalpha()]

# %%
# filter out stop words
from nltk.corpus import stopwords
indian_stop_words = set(stopwords.words('english'))

# %%
indian_stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
indian_words = [word for word in indian_words if not word in indian_stop_words]

# %%
indian_words
# Out:
# ['atms',
#  'become',
#  'virtual',
#  'bank',
#  'branches',
#  'accept',
#  'deposits',
#  'instant',
#  'credit',
#  'idfc',
#  'first',
#  'bank',
#  'seniors',
#  'forgo',
#  'bonus',
#  'amid',
#  'covid',
#  'crisis',
#  'huge',
#  'scam',
#  'yes',
#  'bank',
#  'many',
#  'years',
#  'says',
#  'enforcement',
#  'directorate',
#  'dcb',
#  'banks',
#  'profit',
#  'tax',
#  'declines',
#  'rs',
#  'crore',
#  'q',
#  'retail',
#  'msme',
#  'loans',
#  'get',
#  'cheaper',
#  'rbi',
#  'cuts',
#  'repo',
#  'rate',
#  'surprise',
#  'action',
#  'rbi',
#  'forecasts',
#  'economic',
#  'contraction',
#  'announces',
#  'sharp',
#  'bp',
#  'rate',
#  'cut',
#  'rbi',
#  'extends',
#  'loan',
#  'moratorium',
#  'till',
#  'aug',
#  'silent',
#  'onetime',
#  'restructuring',
#  'covid',
#  'crisis',
#  'slippages',
#  'may',
#  'jump',
#  'rs',
#  'trillion',
#  'says',
#  'india',
#  'ratings',
#  'fm',
#  'sitharaman',
#  'review',
#  'banking',
#  'situation',
# ...

# %%
global_headlines_df['headline']
# Out:
# 0       banking bill negotiators set compromise  plan ...
# 1       managers journal sniffing out drug abusers is ...
# 2       bank of montreal royal bank profits rose in  n...
# 3                     battle over medical costs isnt over
# 4            dow falls      late gm surge stanches losses
#                               ...
# 4841    stocks rise for third straight session better ...
# 4842    sawyer sees strong economy for   years truce o...
# 4843                       oils losses are airlines gains
# 4844    full senate to vote on bernanke panel advances...
# 4845                            reinventing opportunities
# Name: headline, Length: 4846, dtype: object

# %% [markdown]
# ### Stemming, tokenization, filtering stopwords for Global financial news tokenization, filtering stopwords

# %%
global_headlines_df['headline']
# Out:
# 0       banking bill negotiators set compromise  plan ...
# 1       managers journal sniffing out drug abusers is ...
# 2       bank of montreal royal bank profits rose in  n...
# 3                     battle over medical costs isnt over
# 4            dow falls      late gm surge stanches losses
#                               ...
# 4841    stocks rise for third straight session better ...
# 4842    sawyer sees strong economy for   years truce o...
# 4843                       oils losses are airlines gains
# 4844    full senate to vote on bernanke panel advances...
# 4845                            reinventing opportunities
# Name: headline, Length: 4846, dtype: object

# %%
global_article_headlines = global_headlines_df['headline']

# %%
global_article_headlines
# Out:
# 0       banking bill negotiators set compromise  plan ...
# 1       managers journal sniffing out drug abusers is ...
# 2       bank of montreal royal bank profits rose in  n...
# 3                     battle over medical costs isnt over
# 4            dow falls      late gm surge stanches losses
#                               ...
# 4841    stocks rise for third straight session better ...
# 4842    sawyer sees strong economy for   years truce o...
# 4843                       oils losses are airlines gains
# 4844    full senate to vote on bernanke panel advances...
# 4845                            reinventing opportunities
# Name: headline, Length: 4846, dtype: object

# %% [markdown]
# ### Create a list of strings, one for each title

# %%
global_headline_list = [headline for headline in global_article_headlines]

# %%
global_headline_list
# Out:
# ['banking bill negotiators set compromise  plan to widen banks entry to securities business is dropped as vote nears',
#  'managers journal sniffing out drug abusers is no quick fix',
#  'bank of montreal royal bank profits rose in  nd period',
#  'battle over medical costs isnt over',
#  'dow falls      late gm surge stanches losses',
#  'us week ahead of economic summit signals it wants lower interest rates',
#  'net worth not income is right measure of inequality',
#  'the americas ecuador struggles toward a dollar economy',
#  'dollar declines as players take profits from rally and after fed boosts rates',
#  'in europe job protections for older generation are barriers for younger workers earnings gap looms for younger generation dependent on shortterm contracts',
#  'outlook for business investment improves but softness may persist',
#  'tech sector in hiring drive google intel add workers as profits snap back startups also fight for talent',
# ...

# %% [markdown]
# ### Collapse the list of strings into a single long string for processing

# %%
global_big_headline_string = ' '.join(global_headline_list)

# %%
global_big_headline_string
# Out:
# 'banking bill negotiators set compromise  plan to widen banks entry to securities business is dropped as vote nears managers journal sniffing out drug abusers is no quick fix bank of montreal royal bank profits rose in  nd period battle over medical costs isnt over dow falls      late gm surge stanches losses us week ahead of economic summit signals it wants lower interest rates net worth not income is right measure of inequality the americas ecuador struggles toward a dollar economy dollar declines as players take profits from rally and after fed boosts rates in europe job protections for older generation are barriers for younger workers earnings gap looms for younger generation dependent on shortterm contracts outlook for business investment improves but softness may persist tech sector in hiring drive google intel add workers as profits snap back startups also fight for talent feds greenspan refuses to accept blame for recession upturns pace is glacial theyre writing the checks ra
# ...

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# ### Tokenize the string into words

# %%
global_tokens = word_tokenize(global_big_headline_string)

# %%
global_tokens
# Out:
# ['banking',
#  'bill',
#  'negotiators',
#  'set',
#  'compromise',
#  'plan',
#  'to',
#  'widen',
#  'banks',
#  'entry',
#  'to',
#  'securities',
#  'business',
#  'is',
#  'dropped',
#  'as',
#  'vote',
#  'nears',
#  'managers',
#  'journal',
#  'sniffing',
#  'out',
#  'drug',
#  'abusers',
#  'is',
#  'no',
#  'quick',
#  'fix',
#  'bank',
#  'of',
#  'montreal',
#  'royal',
#  'bank',
#  'profits',
#  'rose',
#  'in',
#  'nd',
#  'period',
#  'battle',
#  'over',
#  'medical',
#  'costs',
#  'isnt',
#  'over',
#  'dow',
#  'falls',
#  'late',
#  'gm',
#  'surge',
#  'stanches',
#  'losses',
#  'us',
#  'week',
#  'ahead',
#  'of',
#  'economic',
#  'summit',
#  'signals',
#  'it',
#  'wants',
#  'lower',
#  'interest',
#  'rates',
#  'net',
#  'worth',
#  'not',
#  'income',
#  'is',
#  'right',
#  'measure',
#  'of',
#  'inequality',
#  'the',
#  'americas',
#  'ecuador',
#  'struggles',
#  'toward',
#  'a',
#  'dollar',
#  'economy',
#  'dollar',
#  'declines',
#  'as',
# ...

# %%
nltk.pos_tag(global_tokens)
# Out:
# [('banking', 'NN'),
#  ('bill', 'NN'),
#  ('negotiators', 'NNS'),
#  ('set', 'VBD'),
#  ('compromise', 'NN'),
#  ('plan', 'NN'),
#  ('to', 'TO'),
#  ('widen', 'VB'),
#  ('banks', 'NNS'),
#  ('entry', 'VBP'),
#  ('to', 'TO'),
#  ('securities', 'NNS'),
#  ('business', 'NN'),
#  ('is', 'VBZ'),
#  ('dropped', 'VBN'),
#  ('as', 'IN'),
#  ('vote', 'NN'),
#  ('nears', 'VBZ'),
#  ('managers', 'NNS'),
#  ('journal', 'JJ'),
#  ('sniffing', 'VBG'),
#  ('out', 'RP'),
#  ('drug', 'NN'),
#  ('abusers', 'NNS'),
#  ('is', 'VBZ'),
#  ('no', 'DT'),
#  ('quick', 'JJ'),
#  ('fix', 'NN'),
#  ('bank', 'NN'),
#  ('of', 'IN'),
#  ('montreal', 'JJ'),
#  ('royal', 'JJ'),
#  ('bank', 'NN'),
#  ('profits', 'NNS'),
#  ('rose', 'VBD'),
#  ('in', 'IN'),
#  ('nd', 'JJ'),
#  ('period', 'NN'),
#  ('battle', 'NN'),
#  ('over', 'IN'),
#  ('medical', 'JJ'),
#  ('costs', 'NNS'),
#  ('isnt', 'VBP'),
#  ('over', 'IN'),
#  ('dow', 'NN'),
#  ('falls', 'NNS'),
#  ('late', 'JJ'),
#  ('gm', 'NNS'),
#  ('surge', 'NN'),
# ...

# %% [markdown]
# ### Remove non-alphabetic tokens, such as punctuation

# %%
global_words = [word.lower() for word in global_tokens if word.isalpha()]

# %%
global_words
# Out:
# ['banking',
#  'bill',
#  'negotiators',
#  'set',
#  'compromise',
#  'plan',
#  'to',
#  'widen',
#  'banks',
#  'entry',
#  'to',
#  'securities',
#  'business',
#  'is',
#  'dropped',
#  'as',
#  'vote',
#  'nears',
#  'managers',
#  'journal',
#  'sniffing',
#  'out',
#  'drug',
#  'abusers',
#  'is',
#  'no',
#  'quick',
#  'fix',
#  'bank',
#  'of',
#  'montreal',
#  'royal',
#  'bank',
#  'profits',
#  'rose',
#  'in',
#  'nd',
#  'period',
#  'battle',
#  'over',
#  'medical',
#  'costs',
#  'isnt',
#  'over',
#  'dow',
#  'falls',
#  'late',
#  'gm',
#  'surge',
#  'stanches',
#  'losses',
#  'us',
#  'week',
#  'ahead',
#  'of',
#  'economic',
#  'summit',
#  'signals',
#  'it',
#  'wants',
#  'lower',
#  'interest',
#  'rates',
#  'net',
#  'worth',
#  'not',
#  'income',
#  'is',
#  'right',
#  'measure',
#  'of',
#  'inequality',
#  'the',
#  'americas',
#  'ecuador',
#  'struggles',
#  'toward',
#  'a',
#  'dollar',
#  'economy',
#  'dollar',
#  'declines',
#  'as',
# ...

# %% [markdown]
# ### Filter out stopwords

# %%
from nltk.corpus import stopwords
global_stop_words = set(stopwords.words('english'))

# %%
global_stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
global_words = [word for word in global_words if not word in global_stop_words]

# %%
global_words
# Out:
# ['banking',
#  'bill',
#  'negotiators',
#  'set',
#  'compromise',
#  'plan',
#  'widen',
#  'banks',
#  'entry',
#  'securities',
#  'business',
#  'dropped',
#  'vote',
#  'nears',
#  'managers',
#  'journal',
#  'sniffing',
#  'drug',
#  'abusers',
#  'quick',
#  'fix',
#  'bank',
#  'montreal',
#  'royal',
#  'bank',
#  'profits',
#  'rose',
#  'nd',
#  'period',
#  'battle',
#  'medical',
#  'costs',
#  'isnt',
#  'dow',
#  'falls',
#  'late',
#  'gm',
#  'surge',
#  'stanches',
#  'losses',
#  'us',
#  'week',
#  'ahead',
#  'economic',
#  'summit',
#  'signals',
#  'wants',
#  'lower',
#  'interest',
#  'rates',
#  'net',
#  'worth',
#  'income',
#  'right',
#  'measure',
#  'inequality',
#  'americas',
#  'ecuador',
#  'struggles',
#  'toward',
#  'dollar',
#  'economy',
#  'dollar',
#  'declines',
#  'players',
#  'take',
#  'profits',
#  'rally',
#  'fed',
#  'boosts',
#  'rates',
#  'europe',
#  'job',
#  'protections',
#  'older',
#  'generation',
#  'barriers',
# ...

# %%
indian_words
# Out:
# ['atms',
#  'become',
#  'virtual',
#  'bank',
#  'branches',
#  'accept',
#  'deposits',
#  'instant',
#  'credit',
#  'idfc',
#  'first',
#  'bank',
#  'seniors',
#  'forgo',
#  'bonus',
#  'amid',
#  'covid',
#  'crisis',
#  'huge',
#  'scam',
#  'yes',
#  'bank',
#  'many',
#  'years',
#  'says',
#  'enforcement',
#  'directorate',
#  'dcb',
#  'banks',
#  'profit',
#  'tax',
#  'declines',
#  'rs',
#  'crore',
#  'q',
#  'retail',
#  'msme',
#  'loans',
#  'get',
#  'cheaper',
#  'rbi',
#  'cuts',
#  'repo',
#  'rate',
#  'surprise',
#  'action',
#  'rbi',
#  'forecasts',
#  'economic',
#  'contraction',
#  'announces',
#  'sharp',
#  'bp',
#  'rate',
#  'cut',
#  'rbi',
#  'extends',
#  'loan',
#  'moratorium',
#  'till',
#  'aug',
#  'silent',
#  'onetime',
#  'restructuring',
#  'covid',
#  'crisis',
#  'slippages',
#  'may',
#  'jump',
#  'rs',
#  'trillion',
#  'says',
#  'india',
#  'ratings',
#  'fm',
#  'sitharaman',
#  'review',
#  'banking',
#  'situation',
# ...

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-11-14 00:00:00+00:00  wsj_398284048
# 1 1986-06-16 00:00:00+00:00  wsj_397959018
# 2 2001-05-24 00:00:00+00:00  wsj_398739166
# 3 1986-10-22 00:00:00+00:00  wsj_397957465
# 4 2005-12-08 00:00:00+00:00  wsj_399004010
#
#                                             headline  negative_score  \
# 0  banking bill negotiators set compromise  plan ...           0.000
# 1  managers journal sniffing out drug abusers is ...           0.420
# 2  bank of montreal royal bank profits rose in  n...           0.000
# 3                battle over medical costs isnt over           0.342
# 4       dow falls      late gm surge stanches losses           0.278
#
#    positive_score  neutral_score  compound_vader_score  \
# 0           0.109          0.891                0.2960
# 1           0.000          0.580               -0.7003
# 2           0.244          0.756                0.4404
# 3           0.000          0.658               -0.3818
# ...

# %%
global_headlines_df_1 = global_headlines_df.loc[:,['date','articleid','headline']]

# %%
global_headlines_df_1.head()
# Out:
#                        date      articleid  \
# 0 1991-11-14 00:00:00+00:00  wsj_398284048
# 1 1986-06-16 00:00:00+00:00  wsj_397959018
# 2 2001-05-24 00:00:00+00:00  wsj_398739166
# 3 1986-10-22 00:00:00+00:00  wsj_397957465
# 4 2005-12-08 00:00:00+00:00  wsj_399004010
#
#                                             headline
# 0  banking bill negotiators set compromise  plan ...
# 1  managers journal sniffing out drug abusers is ...
# 2  bank of montreal royal bank profits rose in  n...
# 3                battle over medical costs isnt over
# 4       dow falls      late gm surge stanches losses

# %%
global_headlines_df = global_headlines_df.loc[:,['date','articleid','headline','compound_vader_score']]

# %%
global_headlines_df.head()
# Out:
#                        date      articleid  \
# 0 1991-11-14 00:00:00+00:00  wsj_398284048
# 1 1986-06-16 00:00:00+00:00  wsj_397959018
# 2 2001-05-24 00:00:00+00:00  wsj_398739166
# 3 1986-10-22 00:00:00+00:00  wsj_397957465
# 4 2005-12-08 00:00:00+00:00  wsj_399004010
#
#                                             headline  compound_vader_score
# 0  banking bill negotiators set compromise  plan ...                0.2960
# 1  managers journal sniffing out drug abusers is ...               -0.7003
# 2  bank of montreal royal bank profits rose in  n...                0.4404
# 3                battle over medical costs isnt over               -0.3818
# 4       dow falls      late gm surge stanches losses               -0.4019

# %%
global_headlines_df.loc[global_headlines_df['compound_vader_score'] < 0, 'sentiment_class'] = '0'
global_headlines_df.loc[global_headlines_df['compound_vader_score'] > 0, 'sentiment_class'] = '1'

# %%
global_headlines_df
# Out:
#                           date       articleid  \
# 0    1991-11-14 00:00:00+00:00   wsj_398284048
# 1    1986-06-16 00:00:00+00:00   wsj_397959018
# 2    2001-05-24 00:00:00+00:00   wsj_398739166
# 3    1986-10-22 00:00:00+00:00   wsj_397957465
# 4    2005-12-08 00:00:00+00:00   wsj_399004010
# ...                        ...             ...
# 4841 2060-10-08 00:00:00+00:00  wapo_141184715
# 4842 2052-02-11 00:00:00+00:00  wapo_152454634
# 4843 2009-12-13 00:00:00+00:00  wapo_410349039
# 4844 2009-12-18 00:00:00+00:00  wapo_410346237
# 4845 1995-01-10 00:00:00+00:00  wapo_307808606
#
#                                                headline  compound_vader_score  \
# 0     banking bill negotiators set compromise  plan ...                0.2960
# 1     managers journal sniffing out drug abusers is ...               -0.7003
# 2     bank of montreal royal bank profits rose in  n...                0.4404
# 3                   battle over medical costs isnt over               -0.3818
# ...
